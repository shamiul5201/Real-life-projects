# %% [markdown]
# # Project Name : Employee Evaluation for Promotion using ML and Eval Auto ML

# %% [markdown]
# ![229962-1600x1080-employeereview_new.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Context:

# %% [markdown]
# ### The HR team stored data of promotion cycle last year, which consists of details of all the employees in the company working last year and also if they got promoted or not, but every time this process gets delayed due to so many details available for each employee - it gets difficult to compare and decide.

# %% [markdown]
# ### We will build a model from stored data, that will predict if a person is eligible for promotion or not.

# %% [markdown]
# ### Time Line of the Project:
# - Importing Libraries and DataSet
# - Data Analysis
# - Feature Engineering
# - Model building using ML models
# - Model building and prediction using Auto ML

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# ### Reading the DataSet

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df= pd.read_csv("employee_promotion.csv")

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0            0
# 1                  4           0                60.0            0
# 2                  7           0                50.0            0
# 3                 10           0                50.0            0
# 4                  2           0                73.0            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  awards_won            54808 non-null  int64
#  11  avg_training_score    52248 non-null  float64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 5.4+ MB

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service    awards_won  avg_training_score   is_promoted
# count       54808.000000  54808.000000        52248.000000  54808.000000
# mean            5.865512      0.023172           63.712238      0.085170
# std             4.265094      0.150450           13.521910      0.279137
# min             1.000000      0.000000           39.000000      0.000000
# 25%             3.000000      0.000000           51.000000      0.000000
# 50%             5.000000      0.000000           60.000000      0.000000
# 75%             7.000000      0.000000           77.000000      0.000000
# max            37.000000      1.000000           99.000000      1.000000

# %% [markdown]
# ### Data Analysis and Preprocessing

# %% [markdown]
# #### Null Values

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 0
# avg_training_score      2560
# is_promoted                0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 46375         6915  Sales & Marketing  region_14        Bachelor's      m
# 46376         3030         Technology  region_14        Bachelor's      m
# 46377        74592         Operations  region_27  Master's & above      f
# 46378        13918          Analytics   region_1        Bachelor's      m
# 46379        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# 2                sourcing                1   34                   3.0
# 3                   other                2   39                   1.0
# 4                   other                1   45                   3.0
# ...                   ...              ...  ...                   ...
# 46375               other                2   31                   1.0
# 46376            sourcing                1   48                   3.0
# 46377               other                1   37                   2.0
# 46378               other                1   27                   5.0
# 46379               other                1   27                   1.0
#
#        length_of_service  awards_won  avg_training_score  is_promoted
# 0                      8           0                49.0            0
# 1                      4           0                60.0            0
# 2                      7           0                50.0            0
# 3                     10           0                50.0            0
# 4                      2           0                73.0            0
# ...                  ...         ...                 ...          ...
# 46375                  2           0                49.0            0
# 46376                 17           0                78.0            0
# 46377                  6           0                56.0            0
# 46378                  3           0                79.0            0
# 46379                  5           0                49.0            0
#
# [46380 rows x 13 columns]

# %%
df.drop(columns=['employee_id'], inplace=True)
df.head()
# Out:
#           department     region         education gender recruitment_channel  \
# 0  Sales & Marketing   region_7  Master's & above      f            sourcing
# 1         Operations  region_22        Bachelor's      m               other
# 2  Sales & Marketing  region_19        Bachelor's      m            sourcing
# 3  Sales & Marketing  region_23        Bachelor's      m               other
# 4         Technology  region_26        Bachelor's      m               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  awards_won  \
# 0                1   35                   5.0                  8           0
# 1                1   30                   5.0                  4           0
# 2                1   34                   3.0                  7           0
# 3                2   39                   1.0                 10           0
# 4                1   45                   3.0                  2           0
#
#    avg_training_score  is_promoted
# 0                49.0            0
# 1                60.0            0
# 2                50.0            0
# 3                50.0            0
# 4                73.0            0

# %% [markdown]
# ### Deviding features

# %%
num_features=[i for i in df.columns if df.dtypes[i]!='object']
num_features
# Out:
# ['no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'awards_won',
#  'avg_training_score',
#  'is_promoted']

# %%
cat_features=[i for i in df.columns if df.dtypes[i]=='object']
df[cat_features].nunique()
# Out:
# department              9
# region                 34
# education               3
# gender                  2
# recruitment_channel     3
# dtype: int64

# %%
for i in num_features:
    plt.figsize=(10,5)
    sns.boxplot(y=df[i])
    plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(40, 20))

for i, feature in enumerate(df.columns):
    row = int(i/4)
    col = i%4
    pd.value_counts(df.iloc[:, i]).plot.pie(autopct="%.1f%%", ax=axs[row][col])

plt.suptitle('Distribution of features')
plt.tight_layout()

# %%
columns = [ 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'awards_won', 'avg_training_score', 'is_promoted']
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

for i, feature in enumerate(df[columns]):
    row = int(i/4)
    col = i%4
    sns.distplot(df[columns].iloc[:, i], ax=axs[row][col])

plt.suptitle('Distirbution of features')
plt.tight_layout
# Out:
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# ### Plotting Q-Q Plot

# %%
import scipy.stats as stat
import pylab

# %%
def plot_curve(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    df[feature].hist()
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)
    plt.show()

# %%
for feature in columns:
    plot_curve(df,feature)

# %% [markdown]
# ### We need to do log transformation

# %%
age_log = np.log1p(df['age'])
service_log = np.log1p(df['length_of_service'])
score_log = np.log1p(df['avg_training_score'])

df.insert(6, 'age_log', age_log)
df.insert(9, 'length_of_service_log', service_log)
df.insert(12, 'avg_training_score_log', score_log)

df.head()
# Out:
#           department     region         education gender recruitment_channel  \
# 0  Sales & Marketing   region_7  Master's & above      f            sourcing
# 1         Operations  region_22        Bachelor's      m               other
# 2  Sales & Marketing  region_19        Bachelor's      m            sourcing
# 3  Sales & Marketing  region_23        Bachelor's      m               other
# 4         Technology  region_26        Bachelor's      m               other
#
#    no_of_trainings   age_log  age  previous_year_rating  \
# 0                1  3.583519   35                   5.0
# 1                1  3.433987   30                   5.0
# 2                1  3.555348   34                   3.0
# 3                2  3.688879   39                   1.0
# 4                1  3.828641   45                   3.0
#
#    length_of_service_log  length_of_service  awards_won  \
# 0               2.197225                  8           0
# 1               1.609438                  4           0
# 2               2.079442                  7           0
# 3               2.397895                 10           0
# 4               1.098612                  2           0
#
#    avg_training_score_log  avg_training_score  is_promoted
# 0                3.912023                49.0            0
# 1                4.110874                60.0            0
# 2                3.931826                50.0            0
# 3                3.931826                50.0            0
# 4                4.304065                73.0            0

# %%
log_columns = ['age_log', 'length_of_service_log', 'avg_training_score_log']

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20, 10))

sns.distplot(df['age_log'], ax=ax1)
ax1.set_title('Distribution of age_log')
sns.distplot(df['length_of_service_log'], ax=ax2)
ax2.set_title('Distribution of length_of_service_log')
sns.distplot(df['avg_training_score_log'], ax=ax3)
ax3.set_title('Distribution of avg_training_score_log')

plt.suptitle('Distribution of log converted features', fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/shamiul/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for feature in log_columns:
    plot_curve(df,feature)

# %% [markdown]
# #### Heat Map

# %%
plt.figure(figsize=(10, 8))
plt.title('Correlation of features')
sns.heatmap(df.corr(), annot=True, linewidths=.5, cmap="YlGnBu")
# Out:
# <AxesSubplot:title={'center':'Correlation of features'}>

# %% [markdown]
# ### One Hot Encoding

# %%
df_encoded = pd.get_dummies(df)
df_encoded.head()
# Out:
#    no_of_trainings   age_log  age  previous_year_rating  \
# 0                1  3.583519   35                   5.0
# 1                1  3.433987   30                   5.0
# 2                1  3.555348   34                   3.0
# 3                2  3.688879   39                   1.0
# 4                1  3.828641   45                   3.0
#
#    length_of_service_log  length_of_service  awards_won  \
# 0               2.197225                  8           0
# 1               1.609438                  4           0
# 2               2.079442                  7           0
# 3               2.397895                 10           0
# 4               1.098612                  2           0
#
#    avg_training_score_log  avg_training_score  is_promoted  ...  \
# 0                3.912023                49.0            0  ...
# 1                4.110874                60.0            0  ...
# 2                3.931826                50.0            0  ...
# 3                3.931826                50.0            0  ...
# 4                4.304065                73.0            0  ...
#
#    region_region_8  region_region_9  education_Bachelor's  \
# 0                0                0                     0
# 1                0                0                     1
# 2                0                0                     1
# 3                0                0                     1
# 4                0                0                     1
#
#    education_Below Secondary  education_Master's & above  gender_f  gender_m  \
# 0                          0                           1         1         0
# 1                          0                           0         0         1
# 2                          0                           0         0         1
# 3                          0                           0         0         1
# 4                          0                           0         0         1
#
#    recruitment_channel_other  recruitment_channel_referred  \
# 0                          0                             0
# 1                          1                             0
# 2                          0                             0
# 3                          1                             0
# 4                          1                             0
#
#    recruitment_channel_sourcing
# 0                             1
# 1                             0
# 2                             1
# 3                             0
# 4                             0
#
# [5 rows x 61 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46380 entries, 0 to 46379
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   no_of_trainings               46380 non-null  int64
#  1   age_log                       46380 non-null  float64
#  2   age                           46380 non-null  int64
#  3   previous_year_rating          46380 non-null  float64
#  4   length_of_service_log         46380 non-null  float64
#  5   length_of_service             46380 non-null  int64
#  6   awards_won                    46380 non-null  int64
#  7   avg_training_score_log        46380 non-null  float64
#  8   avg_training_score            46380 non-null  float64
#  9   is_promoted                   46380 non-null  int64
#  10  department_Analytics          46380 non-null  uint8
#  11  department_Finance            46380 non-null  uint8
#  12  department_HR                 46380 non-null  uint8
#  13  department_Legal              46380 non-null  uint8
#  14  department_Operations         46380 non-null  uint8
#  15  department_Procurement        46380 non-null  uint8
#  16  department_R&D                46380 non-null  uint8
#  17  department_Sales & Marketing  46380 non-null  uint8
#  18  department_Technology         46380 non-null  uint8
#  19  region_region_1               46380 non-null  uint8
#  20  region_region_10              46380 non-null  uint8
#  21  region_region_11              46380 non-null  uint8
#  22  region_region_12              46380 non-null  uint8
#  23  region_region_13              46380 non-null  uint8
#  24  region_region_14              46380 non-null  uint8
#  25  region_region_15              46380 non-null  uint8
#  26  region_region_16              46380 non-null  uint8
#  27  region_region_17              46380 non-null  uint8
#  28  region_region_18              46380 non-null  uint8
#  29  region_region_19              46380 non-null  uint8
#  30  region_region_2               46380 non-null  uint8
#  31  region_region_20              46380 non-null  uint8
#  32  region_region_21              46380 non-null  uint8
#  33  region_region_22              46380 non-null  uint8
#  34  region_region_23              46380 non-null  uint8
#  35  region_region_24              46380 non-null  uint8
#  36  region_region_25              46380 non-null  uint8
#  37  region_region_26              46380 non-null  uint8
#  38  region_region_27              46380 non-null  uint8
#  39  region_region_28              46380 non-null  uint8
#  40  region_region_29              46380 non-null  uint8
#  41  region_region_3               46380 non-null  uint8
#  42  region_region_30              46380 non-null  uint8
#  43  region_region_31              46380 non-null  uint8
#  44  region_region_32              46380 non-null  uint8
#  45  region_region_33              46380 non-null  uint8
#  46  region_region_34              46380 non-null  uint8
#  47  region_region_4               46380 non-null  uint8
#  48  region_region_5               46380 non-null  uint8
#  49  region_region_6               46380 non-null  uint8
#  50  region_region_7               46380 non-null  uint8
#  51  region_region_8               46380 non-null  uint8
#  52  region_region_9               46380 non-null  uint8
#  53  education_Bachelor's          46380 non-null  uint8
#  54  education_Below Secondary     46380 non-null  uint8
#  55  education_Master's & above    46380 non-null  uint8
#  56  gender_f                      46380 non-null  uint8
#  57  gender_m                      46380 non-null  uint8
#  58  recruitment_channel_other     46380 non-null  uint8
#  59  recruitment_channel_referred  46380 non-null  uint8
#  60  recruitment_channel_sourcing  46380 non-null  uint8
# dtypes: float64(5), int64(5), uint8(51)
# memory usage: 5.8 MB

# %% [markdown]
# ### Scaling our Data

# %%
from sklearn.preprocessing import StandardScaler
features = np.array(df_encoded.columns).reshape(-1, 1)

for feature in features:
    scaler = StandardScaler()
    scaler.fit(df_encoded[feature])
    df_encoded[feature] = scaler.transform(df_encoded[feature])

df_encoded.head()
# Out:
#    no_of_trainings   age_log       age  previous_year_rating  \
# 0        -0.418611  0.019377 -0.076052              1.324653
# 1        -0.418611 -0.749600 -0.740379              1.324653
# 2        -0.418611 -0.125493 -0.208918             -0.263965
# 3         1.226184  0.561202  0.455409             -1.852582
# 4        -0.418611  1.279937  1.252601             -0.263965
#
#    length_of_service_log  length_of_service  awards_won  \
# 0               0.673784           0.402667   -0.155136
# 1              -0.474482          -0.549239   -0.155136
# 2               0.443690           0.164690   -0.155136
# 3               1.065803           0.878619   -0.155136
# 4              -1.472401          -1.025192   -0.155136
#
#    avg_training_score_log  avg_training_score  is_promoted  ...  \
# 0               -1.177045           -1.111888    -0.310195  ...
# 1               -0.202848           -0.292548    -0.310195  ...
# 2               -1.080029           -1.037403    -0.310195  ...
# 3               -1.080029           -1.037403    -0.310195  ...
# 4                0.743621            0.675764    -0.310195  ...
#
#    region_region_8  region_region_9  education_Bachelor's  \
# 0        -0.109043        -0.083089             -1.474410
# 1        -0.109043        -0.083089              0.678237
# 2        -0.109043        -0.083089              0.678237
# 3        -0.109043        -0.083089              0.678237
# 4        -0.109043        -0.083089              0.678237
#
#    education_Below Secondary  education_Master's & above  gender_f  gender_m  \
# 0                   -0.09548                    1.505848  1.518245 -1.518245
# 1                   -0.09548                   -0.664078 -0.658655  0.658655
# 2                   -0.09548                   -0.664078 -0.658655  0.658655
# 3                   -0.09548                   -0.664078 -0.658655  0.658655
# 4                   -0.09548                   -0.664078 -0.658655  0.658655
#
#    recruitment_channel_other  recruitment_channel_referred  \
# 0                  -1.117074                     -0.146768
# 1                   0.895195                     -0.146768
# 2                  -1.117074                     -0.146768
# 3                   0.895195                     -0.146768
# 4                   0.895195                     -0.146768
#
#    recruitment_channel_sourcing
# 0                      1.166064
# 1                     -0.857586
# 2                      1.166064
# 3                     -0.857586
# 4                     -0.857586
#
# [5 rows x 61 columns]

# %% [markdown]
# ### Spllitting the data

# %%
x = df_encoded.drop(columns=['is_promoted'], inplace=False)
y = df_encoded['is_promoted'].astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=11)

# %%
print('Shape of X_train: ', X_train.shape)
print('Shape of X_test: ', X_test.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Shape of X_train:  (37104, 60)
# Shape of X_test:  (9276, 60)
# Shape of y_train:  (37104,)
# Shape of y_test:  (9276,)

# %% [markdown]
# ## Model Development:

# %% [markdown]
# ### We will use the following models in this project:
# - Decison Tree Classifier
# - Random Forest Classifer
# - Logistc Regression

# %% [markdown]
# ### Let us define a function which will give the different accuracy matrics

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, confusion_matrix, f1_score, precision_recall_curve, roc_curve, plot_roc_curve, plot_precision_recall_curve

# %%
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred, average="macro")
    recall = recall_score(y_test, pred, average="macro")
    f1 = f1_score(y_test, pred, average="macro")
    roc_auc = roc_auc_score(y_test, pred_proba, average="macro")
    print('Confusion Matrix')
    print(confusion)
    print('Accuracy: {0:.4f}, Precision: {1:.4f}, Recall {2:.4f}, F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Decision Tree

# %%
dt_clf = DecisionTreeClassifier()

# %%
dt_clf.fit(X_train, y_train)
dt_pred = dt_clf.predict(X_test)
dt_pred_proba = dt_clf.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test, dt_pred, dt_pred_proba)
# Out:
# Confusion Matrix
# [[7881  592]
#  [ 434  369]]
# Accuracy: 0.8894, Precision: 0.6659, Recall 0.6948, F1: 0.6786, AUC:0.6947

# %%
plot_precision_recall_curve(dt_clf, X_test, y_test)
# Out:
# /home/shamiul/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_precision_recall_curve is deprecated; Function `plot_precision_recall_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: PrecisionRecallDisplay.from_predictions or PrecisionRecallDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Logistic Regression

# %%
lr_clf = LogisticRegression()

# %%
lr_clf.fit(X_train, y_train)
lr_pred = lr_clf.predict(X_test)
lr_pred_proba = lr_clf.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test, lr_pred, lr_pred_proba)
# Out:
# Confusion Matrix
# [[8458   15]
#  [ 515  288]]
# Accuracy: 0.9429, Precision: 0.9466, Recall 0.6784, F1: 0.7452, AUC:0.8070

# %%
plot_precision_recall_curve(lr_clf, X_test, y_test)
# Out:
# /home/shamiul/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_precision_recall_curve is deprecated; Function `plot_precision_recall_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: PrecisionRecallDisplay.from_predictions or PrecisionRecallDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Random Forest

# %%
rf_clf = RandomForestClassifier()

# %%
rf_clf.fit(X_train, y_train)
rf_pred = rf_clf.predict(X_test)
rf_pred_proba = rf_clf.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test, rf_pred, rf_pred_proba)
# Out:
# Confusion Matrix
# [[8444   29]
#  [ 508  295]]
# Accuracy: 0.9421, Precision: 0.9269, Recall 0.6820, F1: 0.7463, AUC:0.8030

# %%
plot_precision_recall_curve(rf_clf, X_test, y_test)
# Out:
# /home/shamiul/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_precision_recall_curve is deprecated; Function `plot_precision_recall_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: PrecisionRecallDisplay.from_predictions or PrecisionRecallDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Using Auto ML

# %% [markdown]
# # EVAL ML : ![64432Screenshot (645).png](data:image/png;base64,...)

# %% [markdown]
# ### EvalML is an open-source AutoML library written in python that automates a large part of the machine learning process and we can easily evaluate which machine learning pipeline works better for the given set of data.

# %% [markdown]
# ### Installing Eval ML

# %%
# !pip install evalml

# %%
# !pip install scikit-learn

# %% [markdown]
# ### We will use the same train and test dataset for this

# %%
import evalml

# %%
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>]

# %%
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(x, y, problem_type='binary')

# %% [markdown]
# **Running the Auto ML to select best Algorithm**

# %%
from evalml.automl import AutoMLSearch
automl = AutoMLSearch(X_train=X_train, y_train=y_train, problem_type='binary')
automl.search()
# Out:
# {1: {'Logistic Regression Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Standard Scaler': '00:07',
#   'Random Forest Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler': '00:04',
#   'Total time of batch': '00:12'},
#  2: {'Logistic Regression Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Standard Scaler + RF Classifier Select From Model': '00:06',
#   'Random Forest Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + RF Classifier Select From Model': '00:05',
#   'Total time of batch': '00:11'},
#  3: {'Elastic Net Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Standard Scaler + Select Columns Transformer': '00:05',
#   'Decision Tree Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Select Columns Transformer': '00:04',
#   'CatBoost Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Select Columns Transformer': '00:04',
#   'XGBoost Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Select Columns Transformer': '00:06',
#   'Extra Trees Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Select Columns Transformer': '00:05',
#   'LightGBM Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Select Columns Transformer': '00:04',
#   'Total time of batch': '00:31'}}

# %%
automl.rankings
# Out:
#     id                                      pipeline_name  search_order  \
# 0   10  LightGBM Classifier w/ Label Encoder + Replace...            10
# 1    8  XGBoost Classifier w/ Label Encoder + Replace ...             8
# 2    1  Logistic Regression Classifier w/ Label Encode...             1
# 3    3  Logistic Regression Classifier w/ Label Encode...             3
# 4    5  Elastic Net Classifier w/ Label Encoder + Repl...             5
# 5    4  Random Forest Classifier w/ Label Encoder + Re...             4
# 6    2  Random Forest Classifier w/ Label Encoder + Re...             2
# 7    9  Extra Trees Classifier w/ Label Encoder + Repl...             9
# 8    6  Decision Tree Classifier w/ Label Encoder + Re...             6
# 9    7  CatBoost Classifier w/ Label Encoder + Replace...             7
# 10   0       Mode Baseline Binary Classification Pipeline             0
#
#     validation_score  mean_cv_score  standard_deviation_cv_score  \
# 0           0.241047       0.241047                     0.000376
# 1           0.242098       0.242098                     0.000154
# 2           0.253244       0.253244                     0.001468
# 3           0.264169       0.264169                     0.007540
# 4           0.269071       0.269071                     0.001417
# 5           0.284748       0.284748                     0.001138
# 6           0.292398       0.292398                     0.000482
# 7           0.294686       0.294686                     0.001131
# 8           0.343909       0.343909                     0.014798
# 9           0.517213       0.517213                     0.001024
# 10          3.031824       3.031824                     0.001612
#
#     percent_better_than_baseline  high_variance_cv  \
# 0                      92.049449             False
# 1                      92.014760             False
# 2                      91.647156             False
# 3                      91.286781             False
# 4                      91.125105             False
# 5                      90.608016             False
# 6                      90.355692             False
# 7                      90.280232             False
# 8                      88.656708             False
# 9                      82.940530             False
# 10                      0.000000             False
#
#                                            parameters
# 0   {'Label Encoder': {'positive_label': None}, 'I...
# 1   {'Label Encoder': {'positive_label': None}, 'I...
# 2   {'Label Encoder': {'positive_label': None}, 'I...
# 3   {'Label Encoder': {'positive_label': None}, 'I...
# 4   {'Label Encoder': {'positive_label': None}, 'I...
# 5   {'Label Encoder': {'positive_label': None}, 'I...
# 6   {'Label Encoder': {'positive_label': None}, 'I...
# 7   {'Label Encoder': {'positive_label': None}, 'I...
# 8   {'Label Encoder': {'positive_label': None}, 'I...
# 9   {'Label Encoder': {'positive_label': None}, 'I...
# 10  {'Label Encoder': {'positive_label': None}, 'B...

# %%
automl.best_pipeline
best_pipeline=automl.best_pipeline

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])
# Out:
# ***********************************************************************************************************************************
# * LightGBM Classifier w/ Label Encoder + Replace Nullable Types Transformer + Imputer + Undersampler + Select Columns Transformer *
# ***********************************************************************************************************************************
#
# Problem Type: binary
# Model Family: LightGBM
#
# Pipeline Steps
# ==============
# 1. Label Encoder
# 	 * positive_label : None
# 2. Replace Nullable Types Transformer
# 3. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 4. Undersampler
# 	 * sampling_ratio : 0.25
# 	 * min_samples : 100
# 	 * min_percentage : 0.1
# 	 * sampling_ratio_dict : None
# 5. Select Columns Transformer
# 	 * columns : ['no_of_trainings', 'age_log', 'age', 'previous_year_rating', 'length_of_service_log', 'length_of_service', 'awards_won', 'avg_training_score_log', 'avg_training_score', 'department_Analytics', 'department_Finance', 'department_Operations', 'department_Procurement', 'department_Sales & Marketing', 'department_Technology', 'region_region_13', 'region_region_15', 'region_region_2', 'region_region_22', 'region_region_26', 'region_region_27', 'region_region_28', 'region_region_4', 'region_region_7', "education_Bachelor's", "education_Master's & above", 'gender_f', 'gender_m', 'recruitment_channel_other', 'recruitment_channel_sourcing']
# 6. LightGBM Classifier
# 	 * boosting_type : gbdt
# 	 * learning_rate : 0.1
# 	 * n_estimators : 100
# 	 * max_depth : 0
# 	 * num_leaves : 31
# 	 * min_child_samples : 20
# 	 * n_jobs : -1
# 	 * bagging_freq : 0
# 	 * bagging_fraction : 0.9
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 4.7 seconds
#
# Cross Validation
# ----------------
#              Log Loss Binary  MCC Binary  Gini   AUC  Precision    F1  Balanced Accuracy Binary  Accuracy Binary # Training # Validation
# 0                      0.241       0.511 0.629 0.814      0.739 0.516                     0.691            0.935     24,736       12,368
# 1                      0.241       0.532 0.602 0.801      0.883 0.499                     0.672            0.939     24,736       12,368
# 2                      0.241       0.481 0.627 0.813      0.663 0.499                     0.690            0.929     24,736       12,368
# mean                   0.241       0.508 0.619 0.810      0.762 0.505                     0.685            0.934          -            -
# std                    0.000       0.026 0.015 0.008      0.112 0.010                     0.011            0.005          -            -
# coef of var            0.002       0.050 0.024 0.009      0.147 0.019                     0.016            0.005          -            -

# %% [markdown]
# ### Predicting the results

# %%
evalml.objectives.get_all_objective_names()
# Out:
# ['expvariance',
#  'maxerror',
#  'medianae',
#  'mse',
#  'mae',
#  'r2',
#  'mean squared log error',
#  'root mean squared log error',
#  'root mean squared error',
#  'mean absolute percentage error',
#  'mcc multiclass',
#  'log loss multiclass',
#  'auc weighted',
#  'auc macro',
#  'auc micro',
#  'recall weighted',
#  'recall macro',
#  'recall micro',
#  'precision weighted',
#  'precision macro',
#  'precision micro',
#  'f1 weighted',
#  'f1 macro',
#  'f1 micro',
#  'balanced accuracy multiclass',
#  'accuracy multiclass',
#  'mcc binary',
#  'log loss binary',
#  'gini',
#  'auc',
#  'recall',
#  'precision',
#  'f1',
#  'balanced accuracy binary',
#  'accuracy binary',
#  'sensitivity at low alert rates',
#  'lead scoring',
#  'fraud cost',
#  'cost benefit matrix']

# %%
best_pipeline.score(X_test, y_test,objectives=["accuracy binary"])
# Out:
# OrderedDict([('Accuracy Binary', 0.9385510996119016)])

# %% [markdown]
# ### We can save and load our model in pickle file also

# %%
best_pipeline.save("model.pkl")
final_model=automl.load('model.pkl')

# %%
pred=final_model.predict(X_test)

# %%
pred
# Out:
# 40585    0
# 15718    0
# 42264    0
# 46363    0
# 37567    0
#         ..
# 18784    0
# 7713     0
# 11045    0
# 40741    0
# 43894    0
# Name: is_promoted, Length: 9276, dtype: int64

# %%
y_test
# Out:
# 40585    0
# 15718    0
# 42264    0
# 46363    0
# 37567    0
#         ..
# 18784    0
# 7713     0
# 11045    0
# 40741    0
# 43894    0
# Name: is_promoted, Length: 9276, dtype: int64
